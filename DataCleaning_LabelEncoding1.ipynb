# %%
import pandas as pd

# %%
df = pd.DataFrame({"names":["Aman","Aman","Jack","Tom","Harsh","Shivam"]})
df
# Out:
#     names
# 0    Aman
# 1    Aman
# 2    Jack
# 3     Tom
# 4   Harsh
# 5  Shivam

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['en_names']=le.fit_transform(df['names'])
df
# Out:
#     names  en_names
# 0    Aman         0
# 1    Aman         0
# 2    Jack         2
# 3     Tom         4
# 4   Harsh         1
# 5  Shivam         3

# %%
dataset = pd.read_csv('loan_data_cleaned.csv')
dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
le1 = LabelEncoder()
dataset['en_Education'] = le1.fit_transform(dataset['Education'])


abc = dataset[['Property_Area','en_Property_Area']]
abc
# Out:
#     Property_Area  en_Property_Area
# 0           Urban                 2
# 1           Rural                 0
# 2           Urban                 2
# 3           Urban                 2
# 4           Urban                 2
# ..            ...               ...
# 609         Rural                 0
# 610         Rural                 0
# 611         Urban                 2
# 612         Urban                 2
# 613     Semiurban                 1
#
# [614 rows x 2 columns]

# %%
xyz = dataset[['en_Education','Education']]
xyz
# Out:
#      en_Education     Education
# 0               0      Graduate
# 1               0      Graduate
# 2               0      Graduate
# 3               1  Not Graduate
# 4               0      Graduate
# ..            ...           ...
# 609             0      Graduate
# 610             0      Graduate
# 611             0      Graduate
# 612             0      Graduate
# 613             0      Graduate
#
# [614 rows x 2 columns]
